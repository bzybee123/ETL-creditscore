# %%
import pandas as pd

file_path = r"C:\Users\shiva\Downloads\credit_customers.csv"
creditscore = pd.read_csv(file_path)

creditscore.head()
# Out:
#   checking_status  duration                  credit_history  \
# 0              <0       6.0  critical/other existing credit
# 1        0<=X<200      48.0                   existing paid
# 2     no checking      12.0  critical/other existing credit
# 3              <0      42.0                   existing paid
# 4              <0      24.0              delayed previously
#
#                purpose  credit_amount    savings_status employment  \
# 0             radio/tv         1169.0  no known savings        >=7
# 1             radio/tv         5951.0              <100     1<=X<4
# 2            education         2096.0              <100     4<=X<7
# 3  furniture/equipment         7882.0              <100     4<=X<7
# 4              new car         4870.0              <100     1<=X<4
#
#    installment_commitment     personal_status other_parties  ...  \
# 0                     4.0         male single          none  ...
# 1                     2.0  female div/dep/mar          none  ...
# ...

# %%
creditscore.columns
# Out:
# Index(['checking_status', 'duration', 'credit_history', 'purpose',
#        'credit_amount', 'savings_status', 'employment',
#        'installment_commitment', 'personal_status', 'other_parties',
#        'residence_since', 'property_magnitude', 'age', 'other_payment_plans',
#        'housing', 'existing_credits', 'job', 'num_dependents', 'own_telephone',
#        'foreign_worker', 'class'],
#       dtype='object')

# %%
creditscore.drop(columns = ["checking_status", "other_parties", "own_telephone"], inplace = True, errors ='ignore')

# %%
creditscore.columns
# Out:
# Index(['duration', 'credit_history', 'purpose', 'credit_amount',
#        'savings_status', 'employment', 'installment_commitment',
#        'personal_status', 'residence_since', 'property_magnitude', 'age',
#        'other_payment_plans', 'housing', 'existing_credits', 'job',
#        'num_dependents', 'foreign_worker', 'class'],
#       dtype='object')

# %%
creditscore.rename(columns = {"duration" : "loan_duration", "employment" : "employment_length", "housing" : "house_ownership"}, inplace = True, errors = "ignore" )

# %%
creditscore.columns
# Out:
# Index(['loan_duration', 'credit_history', 'purpose', 'credit_amount',
#        'savings_status', 'employment_length', 'installment_commitment',
#        'personal_status', 'residence_since', 'property_magnitude', 'age',
#        'other_payment_plans', 'house_ownership', 'existing_credits', 'job',
#        'num_dependents', 'foreign_worker', 'class'],
#       dtype='object')

# %%
creditscore.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
creditscore.isna().sum()
# Out:
# loan_duration             0
# credit_history            0
# purpose                   0
# credit_amount             0
# savings_status            0
# employment_length         0
# installment_commitment    0
# personal_status           0
# residence_since           0
# property_magnitude        0
# age                       0
# other_payment_plans       0
# house_ownership           0
# existing_credits          0
# job                       0
# num_dependents            0
# foreign_worker            0
# class                     0
# dtype: int64

# %%
creditscore["class"]
# Out:
# 0      good
# 1       bad
# 2      good
# 3      good
# 4       bad
#        ...
# 995    good
# 996    good
# 997    good
# 998     bad
# 999    good
# Name: class, Length: 1000, dtype: object

# %%
creditscore["class"].unique()
# Out:
# array(['good', 'bad'], dtype=object)

# %%
creditscore["class"] = creditscore["class"].apply(lambda x : 1 if x == "good"  else 0)

# %%
creditscore.drop(columns = "Foreign_worker", inplace = True)

# %%
creditscore.columns = [i.capitalize() for i in creditscore.columns]

# %%
creditscore
# Out:
#      Loan_duration                  Credit_history              Purpose  \
# 0              6.0  critical/other existing credit             radio/tv
# 1             48.0                   existing paid             radio/tv
# 2             12.0  critical/other existing credit            education
# 3             42.0                   existing paid  furniture/equipment
# 4             24.0              delayed previously              new car
# ..             ...                             ...                  ...
# 995           12.0                   existing paid  furniture/equipment
# 996           30.0                   existing paid             used car
# 997           12.0                   existing paid             radio/tv
# 998           45.0                   existing paid             radio/tv
# 999           45.0  critical/other existing credit             used car
#
#      Credit_amount    Savings_status Employment_length  \
# ...

# %%
# Mapping Employment_length and Savings_status

employment_mapping = { "unemployed" : 0.0, '<1': 0.5, '1<=X<4': 2.5, '4<=X<7': 5.5, '>=7': 7.0} 
creditscore["Employment_length"] = creditscore["Employment_length"].map(employment_mapping)
print(creditscore)
# Out:
#      Loan_duration                  Credit_history              Purpose  \
# 0              6.0  critical/other existing credit             radio/tv
# 1             48.0                   existing paid             radio/tv
# 2             12.0  critical/other existing credit            education
# 3             42.0                   existing paid  furniture/equipment
# 4             24.0              delayed previously              new car
# ..             ...                             ...                  ...
# 995           12.0                   existing paid  furniture/equipment
# 996           30.0                   existing paid             used car
# 997           12.0                   existing paid             radio/tv
# 998           45.0                   existing paid             radio/tv
# 999           45.0  critical/other existing credit             used car
#
#      Credit_amount    Savings_status  Employment_length  \
# ...

# %%
# Mapping 'Savings_status 

savings_mapping = {
    'no known savings': 0.0,
    '<100': 50.0,
    '100<=X<500': 300.0,
    '500<=X<1000': 750.0,
    '>=1000': 1000.0}
creditscore["Savings_status"] = creditscore["Savings_status"].map(savings_mapping)

# %%
creditscore
# Out:
#      Loan_duration                  Credit_history              Purpose  \
# 0              6.0  critical/other existing credit             radio/tv
# 1             48.0                   existing paid             radio/tv
# 2             12.0  critical/other existing credit            education
# 3             42.0                   existing paid  furniture/equipment
# 4             24.0              delayed previously              new car
# ..             ...                             ...                  ...
# 995           12.0                   existing paid  furniture/equipment
# 996           30.0                   existing paid             used car
# 997           12.0                   existing paid             radio/tv
# 998           45.0                   existing paid             radio/tv
# 999           45.0  critical/other existing credit             used car
#
#      Credit_amount  Savings_status  Employment_length  Installment_commitment  \
# ...

# %%
# List of columns to convert

creditscore.categorical_cols = ['Credit_history', 'Purpose', 'Personal_status', 'Property_magnitude',
                    'Other_payment_plans', 'House_ownership', 'Job']

# Convert the selected columns to 'category' data type
for col in categorical_cols:
    creditscore[col] = creditscore[col].astype('category')

# %%
creditscore.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Loan_duration           1000 non-null   float64
#  1   Credit_history          1000 non-null   category
#  2   Purpose                 1000 non-null   category
#  3   Credit_amount           1000 non-null   float64
#  4   Savings_status          1000 non-null   float64
#  5   Employment_length       1000 non-null   float64
#  6   Installment_commitment  1000 non-null   float64
#  7   Personal_status         1000 non-null   category
#  8   Residence_since         1000 non-null   float64
#  9   Property_magnitude      1000 non-null   category
#  10  Age                     1000 non-null   float64
#  11  Other_payment_plans     1000 non-null   category
#  12  House_ownership         1000 non-null   category
#  13  Existing_credits        1000 non-null   float64
# ...

# %%
creditscore
# Out:
#      Loan_duration                  Credit_history              Purpose  \
# 0              6.0  critical/other existing credit             radio/tv
# 1             48.0                   existing paid             radio/tv
# 2             12.0  critical/other existing credit            education
# 3             42.0                   existing paid  furniture/equipment
# 4             24.0              delayed previously              new car
# ..             ...                             ...                  ...
# 995           12.0                   existing paid  furniture/equipment
# 996           30.0                   existing paid             used car
# 997           12.0                   existing paid             radio/tv
# 998           45.0                   existing paid             radio/tv
# 999           45.0  critical/other existing credit             used car
#
#      Credit_amount  Savings_status  Employment_length  Installment_commitment  \
# ...

# %%
creditscore.to_csv(r"C:\Users\Shiva\Downloads\creditscore.csv", index = False)
